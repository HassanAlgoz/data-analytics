# %% [markdown]
# # Visualizing Geographical Data
#
# You will use `pandas` and `seaborn` to solve this exercise.

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### Step 0.
#
# 1. Read the CSV file into a pandas dataframe: `"../datasets/housing/housing.csv"`
# 2. Inspect the first 5 rows

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Step 1.
#
# Use `df.select_dtypes` to see which columns are numeric.

# %%
# YOUR CODE HERE

# %% [markdown]
# You should see:
# - `longitude`
# - `latitude`
# - `population`
# - `median_house_value`

# %% [markdown]
# ### Step 2.
#
# Use the right plot to plot:
#
# - `longitude` along the x-axis
# - `latitude` along the y-axis

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Step 3.
#
# Additional information about these houses can also be represented using:
# - **transparency** (0 to 1) such that density of points can be seen
# - **color** (divergent: -1 to 0 to 1, or gradient: 0 to 1, or discrete for categorical features)
# - **size** (small, medium, large)
# - **shape** (x, o, triangle, rectangle)
# - **time** (animation)
#
# Try:
#
# 1. `alpha=0.1` to set the transparency
# 2. search the docs for how to set color
# 3. search the docs for how to set size

# %%
# YOUR CODE HERE
