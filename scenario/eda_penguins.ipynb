# %% [markdown]
# # EDA Penguins
#
# In this notebook tutorial, we will conduct simple EDA steps on the popular penguins dataset.

# %% [markdown]
# ### 1. Imports

# %%
import seaborn as sns

# %% [markdown]
# ### 2. Load the dataset

# %%
df = sns.load_dataset('penguins')
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
import seaborn as sns

sns.relplot(data=df, x="bill_length_mm", y="bill_depth_mm", col='species', hue='sex')

# %% [markdown]
# - We notice there is no correlation between bill_length and bill_depth in general. Howeever, when we look at each species separately, we see significant positive correlation between the two variables.
# - We also notice lengthier bill in males than in females when looking at each speices separately.

# %%
import pandas as pd

cross = pd.crosstab(df['island'], df['species'], normalize=True)
cross
# Out:
# species      Adelie  Chinstrap    Gentoo
# island
# Biscoe     0.132132   0.000000  0.357357
# Dream      0.165165   0.204204  0.000000
# Torgersen  0.141141   0.000000  0.000000

# %%
sns.heatmap(cross, annot=True)
# Out:
# <Axes: xlabel='species', ylabel='island'>

# %%
sns.swarmplot(df, y='body_mass_g', hue='sex')
# Out:
# <Axes: ylabel='body_mass_g'>

# %%
sns.histplot(df, x='body_mass_g', hue='sex', bins=50, kde=True, fill=False)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %% [markdown]
# ## Feature Engineering
#
# - We might try adding the feature `bill_size` which is the product of `bill_length` and `bill_depth` to see if it has any significance in the model.
# - We might also try `bill_ratio` which is the ratio of `bill_length` to `bill_depth` to see if it has any significance in the model.

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 4         3450.0  Female
# 5         3650.0    Male
# ..           ...     ...
# 338       4925.0  Female
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [333 rows x 7 columns]

# %%
df['bill_size'] = df['bill_length_mm'] * df['bill_depth_mm']
df['bill_ratio'] = df['bill_length_mm'] / df['bill_depth_mm']

# %%
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex  bill_size  bill_ratio
# 0       3750.0    Male     731.17    2.090909
# 1       3800.0  Female     687.30    2.270115
# 2       3250.0  Female     725.40    2.238889
# 4       3450.0  Female     708.31    1.901554
# 5       3650.0    Male     809.58    1.907767

# %%
corr = df.corr(numeric_only=True)

# %%
corr['body_mass_g'].sort_values().plot.barh()
# Out:
# <Axes: >

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# - We notice the highest correlation (0.87) between `flipper_length_mm` and `body_mass_g`.
# - We

# %% [markdown]
# ### 3 Data Overview

# %% [markdown]
# Dataset source: https://github.com/allisonhorst/palmerpenguins

# %%
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]

# %% [markdown]
# We note that features are properly named and don't need renaming or standardization.

# %% [markdown]
# #### Understand the Features
#
# Here is what I found on the internet from: https://www.kaggle.com/code/parulpandey/penguin-dataset-the-new-iris
#
# The dataset consists of 7 columns:
#
# - `species`: penguin species
#     1. Chinstrap
#     2. Adélie
#     3. Gentoo
# - `island`: island name:
#     1. Dream
#     2. Torgersen
#     3. Biscoe (Antarctica)
# - `bill_length_mm`: bill length (mm)
# - `bill_depth_mm`: bill depth (mm)
# - `flipper_length_mm`: flipper length (mm)
# - `body_mass_g`: body mass (g)
# - `sex`: penguin sex

# %% [markdown]
# The original source incuded the following illustrative images, which I have included below:

# %% [markdown]
# Penguin Species:

# %% [markdown]
# <img src="https://github.com/allisonhorst/palmerpenguins/raw/main/man/figures/lter_penguins.png">

# %% [markdown]
# Bill length and Bill depth:

# %% [markdown]
# <img src="https://github.com/allisonhorst/palmerpenguins/raw/main/man/figures/culmen_depth.png">

# %% [markdown]
# #### Dataset Size

# %%
df.shape
# Out:
# (344, 7)

# %% [markdown]
# ## 4. Data Cleaning

# %% [markdown]
# #### Technical Dataframe Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %% [markdown]
# - **missing values**: We notice that there are some missing values in the dataset.
# - **categroical types**: `species`, `island`, and `sex` can be converted to `category` data type instead of the current `object` data type.
# - **numerical types**: To save memory, `bill_length_mm`, `bill_depth_mm`, `flipper_length_mm`, and `body_mass_g` can be converted to `float32` instead of `float64`.

# %% [markdown]
# #### Missing values

# %%
# count missing values
df.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
# percentage of missing values from each column
df.isnull().mean() * 100
# Out:
# species              0.000000
# island               0.000000
# bill_length_mm       0.581395
# bill_depth_mm        0.581395
# flipper_length_mm    0.581395
# body_mass_g          0.581395
# sex                  3.197674
# dtype: float64

# %% [markdown]
# Since missing values are low in number, we can safely drop them.

# %%
df.dropna(inplace=True)

# %% [markdown]
# #### Duplicates
#
# Be sure to drop duplicates if any.

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# #### Data types conversion

# %%
mem_usage_before = df.memory_usage(deep=True)

# %%
# convert categotical types
df['species'] = df['species'].astype('category')
df['island'] = df['island'].astype('category')
df['sex'] = df['sex'].astype('category')

# %%
# convert numerical types
df['bill_depth_mm'] = df['bill_depth_mm'].astype('float32')
df['bill_length_mm'] = df['bill_length_mm'].astype('float32')
df['flipper_length_mm'] = df['flipper_length_mm'].astype('float32')
df['body_mass_g'] = df['body_mass_g'].astype('float32')

# %%
mem_usage_after = df.memory_usage(deep=True)
print('memory saved:', (mem_usage_before - mem_usage_after).sum() // 1024, 'KB')
# Out:
# memory saved: 5 KB

# %% [markdown]
# #### Detect inconsistency in categorical values

# %% [markdown]
# The categorical columns should be checked for any inconsistencies. For example. We look for lowercase, uppercase, or inconsistent use of codes (e.g., "M", "F") with non-codes (e.g., "Male", "Female")  in the `sex` column.

# %%
print(df['species'].unique())
print(df['island'].unique())
print(df['sex'].unique())
# Out:
# ['Adelie' 'Chinstrap' 'Gentoo']
# ['Torgersen' 'Biscoe' 'Dream']
# ['Male' 'Female']

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# #### Distribution of categorical features

# %%
# categorical columns
df.describe(exclude='number').T
# Out:
#         count unique     top freq
# species   333      3  Adelie  146
# island    333      3  Biscoe  163
# sex       333      2    Male  168

# %%
species = df['species'].value_counts()
island = df['island'].value_counts()
sex = df['sex'].value_counts()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 3, figsize=(15, 5), sharey=True)

species.plot(kind='bar', ax=ax[0], color='skyblue', rot=0)
ax[0].set_title('Species')
ax[0].set_ylabel('Count')
ax[0].set_xlabel('Species')

island.plot(kind='bar', ax=ax[1], color='lightgreen', rot=0)
ax[1].set_title('Island')
ax[1].set_ylabel('Count')
ax[1].set_xlabel('Island')

sex.plot(kind='bar', ax=ax[2], color='salmon', rot=0)
ax[2].set_title('Sex')
ax[2].set_ylabel('Count')
ax[2].set_xlabel('Sex')
# Out:
# Text(0.5, 0, 'Sex')

# %%
df['species'].value_counts().plot.pie(autopct='%1.0f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# Good enough proportions. No need to worry about this.

# %%
df['island'].value_counts().plot.pie(autopct='%1.0f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# Good enough proportions. No need to worry about this.

# %%
df['sex'].value_counts().plot.pie(autopct='%1.0f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# Equal proportions. No need to worry about this.

# %% [markdown]
# #### Distribution of numerical features

# %%
# numerical columns
df.describe(include='number').T
# Out:
#                    count         mean         std     min     25%     50%  \
# bill_length_mm     333.0    43.992793    5.468668    32.1    39.5    44.5
# bill_depth_mm      333.0    17.164865    1.969235    13.1    15.6    17.3
# flipper_length_mm  333.0   200.966967   14.015765   172.0   190.0   197.0
# body_mass_g        333.0  4207.057057  805.215802  2700.0  3550.0  4050.0
#
#                       75%     max
# bill_length_mm       48.6    59.6
# bill_depth_mm        18.7    21.5
# flipper_length_mm   213.0   231.0
# body_mass_g        4775.0  6300.0

# %% [markdown]
# ## Bivariate Analysis
#
# #### Correlation between numerical features
#
# Let's find out if there is any correlation between numerical features.

# %%
numerical_corr = df.select_dtypes(include='number').corr()
sns.heatmap(numerical_corr, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Observations:
#
# 1. We notice high correlation between flipper length and body mass (0.87).
# 2. We also notice high correlation between flipper length and bill length (0.65).
# 3. There is little correlation between bill depth and bill length (-0.23).

# %% [markdown]
# #### Hypothesize and test
#
# We think that penguins may differ in terms of body mass between species, as well as by gender.
#
# A boxplot can be used to verify this hypothesis.

# %%
sns.boxplot(data=df, x='species', y='body_mass_g', hue='sex')
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %% [markdown]
# Observations:
#
# 1. Our assumption seems correct (at least visually); i.e., Gentoo penguins are heavier than Adélie and Chinstrap penguins.
# 2. We were also right about females' weight. Females are lighter across all species!

# %%
# plot numerical columns
sns.pairplot(df, hue='species')

# %% [markdown]
# - Distribution plots can tell us a lot about each species.
# - Scatter plots can tell us about the relationship between features.
