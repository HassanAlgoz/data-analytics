# %% [markdown]
# # EDA on California Housing Dataset

# %%
import pandas as pd
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# # Get the Data

# %%
housing = pd.read_csv("../datasets/housing/housing.csv")
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
df_num = housing.select_dtypes(include='number')
df_cat = housing.select_dtypes(include='object')

# %%
df_num.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
df_num.describe().T
# Out:
#                       count           mean            std         min  \
# longitude           20640.0    -119.569704       2.003532   -124.3500
# latitude            20640.0      35.631861       2.135952     32.5400
# housing_median_age  20640.0      28.639486      12.585558      1.0000
# total_rooms         20640.0    2635.763081    2181.615252      2.0000
# total_bedrooms      20433.0     537.870553     421.385070      1.0000
# population          20640.0    1425.476744    1132.462122      3.0000
# households          20640.0     499.539680     382.329753      1.0000
# median_income       20640.0       3.870671       1.899822      0.4999
# median_house_value  20640.0  206855.816909  115395.615874  14999.0000
#
#                             25%          50%           75%          max
# longitude             -121.8000    -118.4900    -118.01000    -114.3100
# latitude                33.9300      34.2600      37.71000      41.9500
# ...

# %%
df_cat.describe().T
# Out:
#                  count unique        top  freq
# ocean_proximity  20640      5  <1H OCEAN  9136

# %%
df_num.hist(bins=50, figsize=(20,15));

# %% [markdown]
# Observations:
#
# - housing median age follows almost normal distribution, with a weired peak (possible outliers) after 50.
# - population follows an expoentnail distribution, suggesting some blocks are way more dense than others.

# %%
df_cat.value_counts().plot.bar(rot=0)
# Out:
# <Axes: xlabel='ocean_proximity'>

# %% [markdown]
# Observations:
#
# - Distribution of ...

# %% [markdown]
# Preprocessing ...

# %% [markdown]
# # Let's do some visualization

# %% [markdown]
# ## Visualizing Geographical Data

# %%
housing.plot(kind="scatter", x="longitude", y="latitude")
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %%
housing.plot(kind="scatter", x="longitude", y="latitude", alpha=0.1)
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %% [markdown]
# Additional information about these houses can be represented in:
# - **shape** (x, o, triangle, rectangle)
# - **color** (divergent: -1 to 0 to 1, or gradient: 0 to 1, or discrete for categorical features)
# - **size** (small, medium, large)
# - **transparency** (0 to 1) such that density of points can be seen
# - **time** (animation)

# %%
housing.plot(
    kind="scatter",
    label="population",
    x="longitude",
    y="latitude",
    s=housing["population"] / 100, # radius of each circle represents the district's population
    c="median_house_value", # color represents the price
    alpha=0.4, # lower transparency to see overlapping data points
    cmap=plt.get_cmap("jet"),
    colorbar=True,
    figsize=(10, 7),
    sharex=False,
)
plt.legend()

# %% [markdown]
# ## Let's create new features (Feature Engineering)

# %%
housing["median_income"].hist(bins=50)
# Out:
# <Axes: >

# %%
housing["income_cat"] = pd.cut(housing["median_income"],
                               bins=[0., 1.5, 3.0, 4.5, 6., np.inf],
                               labels=[1, 2, 3, 4, 5])

# %%
housing["income_cat"].value_counts(sort=False).plot.bar(rot=0)
# Out:
# <Axes: xlabel='income_cat'>

# %%
housing["rooms_per_household"] = housing["total_rooms"] / housing["households"]
housing["bedrooms_per_room"] = housing["total_bedrooms"] / housing["total_rooms"]
housing["population_per_household"] = housing["population"] / housing["households"]

# %%
housing.describe().T
# Out:
#                             count           mean            std           min  \
# longitude                 20640.0    -119.569704       2.003532   -124.350000
# latitude                  20640.0      35.631861       2.135952     32.540000
# housing_median_age        20640.0      28.639486      12.585558      1.000000
# total_rooms               20640.0    2635.763081    2181.615252      2.000000
# total_bedrooms            20433.0     537.870553     421.385070      1.000000
# population                20640.0    1425.476744    1132.462122      3.000000
# households                20640.0     499.539680     382.329753      1.000000
# median_income             20640.0       3.870671       1.899822      0.499900
# median_house_value        20640.0  206855.816909  115395.615874  14999.000000
# rooms_per_household       20640.0       5.429000       2.474173      0.846154
# bedrooms_per_room         20433.0       0.213039       0.057983      0.100000
# ...

# %% [markdown]
# ### Let's look at the correlation matrix with median_house_value

# %%
corr_matrix = housing.select_dtypes('number').corr()
corr_matrix["median_house_value"].sort_values(ascending=False).plot.barh()
# Out:
# <Axes: >

# %% [markdown]
# Observations:
#
# - ...

# %% [markdown]
# ## Handle Missing Values

# %% [markdown]
# ```python
# housing.dropna(subset=["total_bedrooms"])    # option 1
# housing.drop("total_bedrooms", axis=1)       # option 2
# median = housing["total_bedrooms"].median()  # option 3
# housing["total_bedrooms"].fillna(median, inplace=True)
# ```
#
# To demonstrate each of them, let's create a copy of the housing dataset, but keeping only the rows that contain at least one null. Then it will be easier to visualize exactly what each option does:

# %%
sample_incomplete_rows = housing[housing.isnull().any(axis=1)].head()
sample_incomplete_rows
# Out:
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 290    -122.16     37.77                47.0       1256.0             NaN
# 341    -122.17     37.75                38.0        992.0             NaN
# 538    -122.28     37.78                29.0       5154.0             NaN
# 563    -122.24     37.75                45.0        891.0             NaN
# 696    -122.10     37.69                41.0        746.0             NaN
#
#      population  households  median_income ocean_proximity income_cat  \
# 290       570.0       218.0         4.3750        NEAR BAY          3
# 341       732.0       259.0         1.6196        NEAR BAY          2
# 538      3741.0      1273.0         2.5762        NEAR BAY          2
# 563       384.0       146.0         4.9489        NEAR BAY          4
# 696       387.0       161.0         3.9063        NEAR BAY          3
#
#      rooms_per_household  bedrooms_per_room  population_per_household
# ...

# %%
sample_incomplete_rows.dropna(subset=["total_bedrooms"])    # option 1
# Out:
# Empty DataFrame
# Columns: [longitude, latitude, housing_median_age, total_rooms, total_bedrooms, population, households, median_income, ocean_proximity, income_cat, rooms_per_household, bedrooms_per_room, population_per_household]
# Index: []

# %%
sample_incomplete_rows.drop("total_bedrooms", axis=1)       # option 2
# Out:
#      longitude  latitude  housing_median_age  total_rooms  population  \
# 290    -122.16     37.77                47.0       1256.0       570.0
# 341    -122.17     37.75                38.0        992.0       732.0
# 538    -122.28     37.78                29.0       5154.0      3741.0
# 563    -122.24     37.75                45.0        891.0       384.0
# 696    -122.10     37.69                41.0        746.0       387.0
#
#      households  median_income ocean_proximity income_cat  \
# 290       218.0         4.3750        NEAR BAY          3
# 341       259.0         1.6196        NEAR BAY          2
# 538      1273.0         2.5762        NEAR BAY          2
# 563       146.0         4.9489        NEAR BAY          4
# 696       161.0         3.9063        NEAR BAY          3
#
#      rooms_per_household  bedrooms_per_room  population_per_household
# 290             5.761468                NaN                  2.614679
# ...

# %%
median = housing["total_bedrooms"].median()
sample_incomplete_rows["total_bedrooms"].fillna(median, inplace=True) # option 3

# %%
sample_incomplete_rows
# Out:
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 290    -122.16     37.77                47.0       1256.0           435.0
# 341    -122.17     37.75                38.0        992.0           435.0
# 538    -122.28     37.78                29.0       5154.0           435.0
# 563    -122.24     37.75                45.0        891.0           435.0
# 696    -122.10     37.69                41.0        746.0           435.0
#
#      population  households  median_income ocean_proximity income_cat  \
# 290       570.0       218.0         4.3750        NEAR BAY          3
# 341       732.0       259.0         1.6196        NEAR BAY          2
# 538      3741.0      1273.0         2.5762        NEAR BAY          2
# 563       384.0       146.0         4.9489        NEAR BAY          4
# 696       387.0       161.0         3.9063        NEAR BAY          3
#
#      rooms_per_household  bedrooms_per_room  population_per_household
# ...

# %% [markdown]
# ### Outlier Treatment

# %%
housing['population'].plot.hist(bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
log_population = np.log1p(housing['population'])
housing['population_norm'] = log_population[log_population < log_population.quantile(0.99)]
housing['population_norm'].plot.hist(bins=50, xlabel="population normalized")
# Out:
# <Axes: xlabel='population normalized', ylabel='Frequency'>
