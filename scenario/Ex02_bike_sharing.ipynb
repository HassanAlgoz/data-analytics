# %% [markdown]
# # Bike Sharing in the Bay Area
#
# We end this chapter by using all the methods we have learned to examine a new and large dataset. We will also introduce `map_table`, a powerful visualization tool.
#
# The [Bay Area Bike Share](http://www.bayareabikeshare.com/) service published a [dataset](http://www.bayareabikeshare.com/open-data) describing every bicycle rental from September 2014 to August 2015 in their system. There were 354,152 rentals in all. The columns are:
#
# - An ID for the rental
# - Duration of the rental, in seconds
# - Start date
# - Name of the Start Station and code for Start Terminal
# - Name of the End Station and code for End Terminal
# - A serial number for the bike
# - Subscriber type and zip code

# %% [markdown]
# Credit: this notebook is adapted from: [Chapter 8.5 - Computational and Inferential Thinking: The Foundations of Data Science](https://inferentialthinking.com/chapters/08/5/Bike_Sharing_in_the_Bay_Area.html)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path_data = '../datasets/trip/'

trips = pd.read_csv(path_data + 'trip.csv')
trips.head()
# Out:
#    Trip ID  Duration       Start Date                         Start Station  \
# 0   913460       765  8/31/2015 23:26  Harry Bridges Plaza (Ferry Building)
# 1   913459      1036  8/31/2015 23:11           San Antonio Shopping Center
# 2   913455       307  8/31/2015 23:13                        Post at Kearny
# 3   913454       409  8/31/2015 23:10                    San Jose City Hall
# 4   913453       789  8/31/2015 23:09                 Embarcadero at Folsom
#
#    Start Terminal         End Date                               End Station  \
# 0              50  8/31/2015 23:39  San Francisco Caltrain (Townsend at 4th)
# 1              31  8/31/2015 23:28                   Mountain View City Hall
# 2              47  8/31/2015 23:18                         2nd at South Park
# 3              10  8/31/2015 23:17                       San Salvador at 1st
# 4              51  8/31/2015 23:22                    Embarcadero at Sansome
#
#    End Terminal  Bike # Subscriber Type Zip Code
# 0            70     288      Subscriber     2139
# 1            27      35      Subscriber    95032
# 2            64     468      Subscriber    94107
# 3             8      68      Subscriber    95113
# 4            60     487        Customer     9069

# %% [markdown]
# We'll focus only on the *free trips*, which are trips that last less than 1800 seconds (half an hour). There is a charge for longer trips.
#
# The histogram below shows that most of the trips took around 10 minutes (600 seconds) or so. Very few took near 30 minutes (1800 seconds), possibly because people try to return the bikes before the cutoff time so as not to have to pay.

# %%
commute = trips[trips['Duration'] < 1800]
commute.plot.hist(y='Duration', bins=30, title='Trip Durations', alpha=0.5)
plt.xlabel('Duration (seconds)')
plt.show()

# %% [markdown]
# We can get more detail by specifying a larger number of bins. But the overall shape doesn't change much.

# %%
commute = trips[trips['Duration'] < 1800]
commute.plot.hist(y='Duration', bins=80, title='Trip Durations', alpha=0.5)
plt.xlabel('Duration (seconds)')
plt.show()

# %% [markdown]
# ## Exploring the Data with `group` and `pivot`
#
# We can use `group` to identify the most highly used Start Station:

# %%
starts = commute.groupby('Start Station').size().reset_index(name='count').sort_values(by='count', ascending=False)
starts.head()
# Out:
#                                     Start Station  count
# 49       San Francisco Caltrain (Townsend at 4th)  25858
# 50        San Francisco Caltrain 2 (330 Townsend)  21523
# 23           Harry Bridges Plaza (Ferry Building)  15543
# 65  Temporary Transbay Terminal (Howard at Beale)  14298
# 2                                 2nd at Townsend  13674

# %% [markdown]
# The largest number of trips started at the Caltrain Station on Townsend and 4th in San Francisco. People take the train into the city, and then use a shared bike to get to their next destination.

# %% [markdown]
# ### Count the number of trips, for each start and end stations

# %% [markdown]
# The `group` method can also be used to classify the rentals by both Start Station and End Station.

# %%
start_end = commute.groupby(['Start Station', 'End Station']).size()
start_end.head()
# Out:
# Start Station  End Station
# 2nd at Folsom  2nd at Folsom         54
#                2nd at South Park    295
#                2nd at Townsend      437
#                5th at Howard        113
#                Beale at Market      127
# dtype: int64

# %% [markdown]
# Note that `groupby` results in multi-indexed DataFrame where `' 'Start Station'` and `'End Station'` are the 1st level, and 2nd level indexes respectively.

# %%
start_end.index
# Out:
# MultiIndex([(                                '2nd at Folsom', ...),
#             (                                '2nd at Folsom', ...),
#             (                                '2nd at Folsom', ...),
#             (                                '2nd at Folsom', ...),
#             (                                '2nd at Folsom', ...),
#             (                                '2nd at Folsom', ...),
#             (                                '2nd at Folsom', ...),
#             (                                '2nd at Folsom', ...),
#             (                                '2nd at Folsom', ...),
#             (                                '2nd at Folsom', ...),
#             ...
#             ('Yerba Buena Center of the Arts (3rd @ Howard)', ...),
#             ('Yerba Buena Center of the Arts (3rd @ Howard)', ...),
#             ('Yerba Buena Center of the Arts (3rd @ Howard)', ...),
#             ('Yerba Buena Center of the Arts (3rd @ Howard)', ...),
#             ('Yerba Buena Center of the Arts (3rd @ Howard)', ...),
#             ('Yerba Buena Center of the Arts (3rd @ Howard)', ...),
#             ('Yerba Buena Center of the Arts (3rd @ Howard)', ...),
#             ('Yerba Buena Center of the Arts (3rd @ Howard)', ...),
#             ('Yerba Buena Center of the Arts (3rd @ Howard)', ...),
#             ('Yerba Buena Center of the Arts (3rd @ Howard)', ...)],
#            names=['Start Station', 'End Station'], length=1629)

# %% [markdown]
# Let's use `reset_index` to convert the result of the `groupby` operation from a multi-indexed DataFrame to a regular DataFrame.
#
# The `name='count'` ensures the aggregate-value column is given a name.

# %%
start_end = start_end.reset_index(name='count')
start_end.head()
# Out:
#    Start Station        End Station  count
# 0  2nd at Folsom      2nd at Folsom     54
# 1  2nd at Folsom  2nd at South Park    295
# 2  2nd at Folsom    2nd at Townsend    437
# 3  2nd at Folsom      5th at Howard    113
# 4  2nd at Folsom    Beale at Market    127

# %% [markdown]
# Fifty-four trips both started and ended at the station on 2nd at Folsom. A much large number (437) were between 2nd at Folsom and 2nd at Townsend.
#
# ### Using `pivot` to show all combinations
#
# The `pivot` method does the same classification but displays its results in a contingency table that shows all possible combinations of Start and End Stations, even though some of them didn't correspond to any trips. Remember that the first argument of a `pivot` statement specifies the column labels of the pivot table; the second argument labels the rows.
#
# There is a train station as well as a Bay Area Rapid Transit (BART) station near Beale at Market, explaining the high number of trips that start and end there.

# %%
pivot_table = commute.pivot_table(index='Start Station', columns='End Station', values='Duration', aggfunc='count', fill_value=0)
pivot_table.head()
# Out:
# End Station        2nd at Folsom  2nd at South Park  2nd at Townsend  \
# Start Station
# 2nd at Folsom                 54                295              437
# 2nd at South Park            190                164              151
# 2nd at Townsend              554                 71              185
# 5th at Howard                107                180               92
# Adobe on Almaden               0                  0                0
#
# End Station        5th at Howard  Adobe on Almaden  Arena Green / SAP Center  \
# Start Station
# 2nd at Folsom                113                 0                         0
# 2nd at South Park            177                 0                         0
# 2nd at Townsend              148                 0                         0
# 5th at Howard                 83                 0                         0
# Adobe on Almaden               0                11                         7
#
# End Station        Beale at Market  Broadway St at Battery St  \
# Start Station
# 2nd at Folsom                  127                         67
# 2nd at South Park               79                         89
# 2nd at Townsend                183                        279
# 5th at Howard                   59                        119
# Adobe on Almaden                 0                          0
#
# End Station        California Ave Caltrain Station  \
# Start Station
# 2nd at Folsom                                    0
# 2nd at South Park                                0
# 2nd at Townsend                                  0
# 5th at Howard                                    0
# Adobe on Almaden                                 0
#
# End Station        Castro Street and El Camino Real  ...  \
# Start Station                                        ...
# 2nd at Folsom                                     0  ...
# 2nd at South Park                                 0  ...
# 2nd at Townsend                                   0  ...
# 5th at Howard                                     0  ...
# Adobe on Almaden                                  0  ...
#
# End Station        South Van Ness at Market  Spear at Folsom  St James Park  \
# Start Station
# 2nd at Folsom                            46              327              0
# 2nd at South Park                        41              209              0
# 2nd at Townsend                          50              407              0
# 5th at Howard                           102              100              0
# Adobe on Almaden                          0                0             10
#
# End Station        Stanford in Redwood City  Steuart at Market  \
# Start Station
# 2nd at Folsom                             0                128
# 2nd at South Park                         0                224
# 2nd at Townsend                           0               1644
# 5th at Howard                             0                371
# Adobe on Almaden                          0                  0
#
# End Station        Temporary Transbay Terminal (Howard at Beale)  \
# Start Station
# 2nd at Folsom                                                414
# 2nd at South Park                                            437
# 2nd at Townsend                                              486
# 5th at Howard                                                561
# Adobe on Almaden                                               0
#
# End Station        Townsend at 7th  University and Emerson  \
# Start Station
# 2nd at Folsom                  347                       0
# 2nd at South Park              309                       0
# 2nd at Townsend                418                       0
# 5th at Howard                  313                       0
# Adobe on Almaden                 0                       0
#
# End Station        Washington at Kearny  \
# Start Station
# 2nd at Folsom                       142
# 2nd at South Park                   142
# 2nd at Townsend                      72
# 5th at Howard                        47
# Adobe on Almaden                      0
#
# End Station        Yerba Buena Center of the Arts (3rd @ Howard)
# Start Station
# 2nd at Folsom                                                 83
# 2nd at South Park                                            180
# 2nd at Townsend                                              174
# 5th at Howard                                                 90
# Adobe on Almaden                                               0
#
# [5 rows x 70 columns]

# %% [markdown]
# ### Shortest Time

# %% [markdown]
# We can also use `pivot` to find the shortest time of the rides between Start and End Stations. Here `pivot` has been given `Duration` as the optional `values` argument, and `min` as the function which to perform on the values in each cell.

# %%
pivot_table_min = commute.pivot_table(index='Start Station', columns='End Station', values='Duration', aggfunc='min', fill_value=0)
pivot_table_min.head()
# Out:
# End Station        2nd at Folsom  2nd at South Park  2nd at Townsend  \
# Start Station
# 2nd at Folsom                 61                 61              137
# 2nd at South Park             97                 60               67
# 2nd at Townsend              164                 77               60
# 5th at Howard                268                 86              423
# Adobe on Almaden               0                  0                0
#
# End Station        5th at Howard  Adobe on Almaden  Arena Green / SAP Center  \
# Start Station
# 2nd at Folsom                215                 0                         0
# 2nd at South Park            300                 0                         0
# 2nd at Townsend              384                 0                         0
# 5th at Howard                 68                 0                         0
# Adobe on Almaden               0                84                       305
#
# End Station        Beale at Market  Broadway St at Battery St  \
# Start Station
# 2nd at Folsom                  219                        351
# 2nd at South Park              343                        424
# 2nd at Townsend                417                        499
# 5th at Howard                  387                        555
# Adobe on Almaden                 0                          0
#
# End Station        California Ave Caltrain Station  \
# Start Station
# 2nd at Folsom                                    0
# 2nd at South Park                                0
# 2nd at Townsend                                  0
# 5th at Howard                                    0
# Adobe on Almaden                                 0
#
# End Station        Castro Street and El Camino Real  ...  \
# Start Station                                        ...
# 2nd at Folsom                                     0  ...
# 2nd at South Park                                 0  ...
# 2nd at Townsend                                   0  ...
# 5th at Howard                                     0  ...
# Adobe on Almaden                                  0  ...
#
# End Station        South Van Ness at Market  Spear at Folsom  St James Park  \
# Start Station
# 2nd at Folsom                           673              154              0
# 2nd at South Park                       801              219              0
# 2nd at Townsend                         727              242              0
# 5th at Howard                           383              382              0
# Adobe on Almaden                          0                0            409
#
# End Station        Stanford in Redwood City  Steuart at Market  \
# Start Station
# 2nd at Folsom                             0                219
# 2nd at South Park                         0                322
# 2nd at Townsend                           0                312
# 5th at Howard                             0                384
# Adobe on Almaden                          0                  0
#
# End Station        Temporary Transbay Terminal (Howard at Beale)  \
# Start Station
# 2nd at Folsom                                                112
# 2nd at South Park                                            195
# 2nd at Townsend                                              261
# 5th at Howard                                                279
# Adobe on Almaden                                               0
#
# End Station        Townsend at 7th  University and Emerson  \
# Start Station
# 2nd at Folsom                  399                       0
# 2nd at South Park              324                       0
# 2nd at Townsend                319                       0
# 5th at Howard                  330                       0
# Adobe on Almaden                 0                       0
#
# End Station        Washington at Kearny  \
# Start Station
# 2nd at Folsom                       266
# 2nd at South Park                   378
# 2nd at Townsend                     464
# 5th at Howard                       269
# Adobe on Almaden                      0
#
# End Station        Yerba Buena Center of the Arts (3rd @ Howard)
# Start Station
# 2nd at Folsom                                                145
# 2nd at South Park                                            212
# 2nd at Townsend                                              299
# 5th at Howard                                                128
# Adobe on Almaden                                               0
#
# [5 rows x 70 columns]

# %% [markdown]
# Someone had a very quick trip (271 seconds, or about 4.5 minutes) from Beale at Market to 2nd at Folsom, about five blocks away. There are no bike trips between the 2nd Avenue stations and Adobe on Almaden, because the latter is in a different city.

# %% [markdown]
# ## Drawing Maps
# The table `stations` contains geographical information about each bike station, including latitude, longitude, and a "landmark" which is the name of the city where the station is located.

# %%
stations = pd.read_csv(path_data + 'station.csv')
stations.head()
# Out:
#    station_id                               name        lat        long  \
# 0           2  San Jose Diridon Caltrain Station  37.329732 -121.901782
# 1           3              San Jose Civic Center  37.330698 -121.888979
# 2           4             Santa Clara at Almaden  37.333988 -121.894902
# 3           5                   Adobe on Almaden  37.331415 -121.893200
# 4           6                   San Pedro Square  37.336721 -121.894074
#
#    dockcount  landmark installation
# 0         27  San Jose     8/6/2013
# 1         15  San Jose     8/5/2013
# 2         11  San Jose     8/6/2013
# 3         19  San Jose     8/5/2013
# 4         15  San Jose     8/7/2013

# %% [markdown]
# We can draw a map of where the stations are located, using `Marker.map_table`. The function operates on a table, whose columns are (in order) latitude, longitude, and an optional identifier for each point.

# %%
import folium

def plot_map(data, lat_col='lat', long_col='long', label_col=None):
    m = folium.Map(location=[data[lat_col].mean(), data[long_col].mean()], zoom_start=10)
    for idx, row in data.iterrows():
        if label_col:
            folium.Marker([row[lat_col], row[long_col]], popup=row[label_col]).add_to(m)
        else:
            folium.Marker([row[lat_col], row[long_col]]).add_to(m)
    return m

# %%
stations_map = plot_map(stations, lat_col='lat', long_col='long', label_col='name')
stations_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c0455ae9b070d3b3e23415890bd30158 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c0455ae9b070d3b3e23415890bd30158&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c0455ae9b070d3b3e23415890bd30158 = L.map(
#                 &quot;map_c0455ae9b070d3b3e23415890bd30158&quot;,
#                 {
#                     center: [37.59024338428571, -122.21841616428571],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_967a5b395cd8d809ce00cdd443eb6f05 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_967a5b395cd8d809ce00cdd443eb6f05.addTo(map_c0455ae9b070d3b3e23415890bd30158);
#
#
#             var marker_161cba16fceb34f8065b08ff92438e22 = L.marker(
#                 [37.329732, -121.901782],
#                 {}
#             ).addTo(map_c0455ae9b070d3b3e23415890bd30158);
#
#
#         var popup_f47f202a7ae7be2fe2a7682be72d19cf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a888bdd74671f0a6b4c0684fc8b62bf3 = $(`&lt;div id=&quot;html_a888bdd74671f0a6b4c0684fc8b62bf3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;San Jose Diridon Caltrain Station&lt;/div&gt;`)[0];
#                 popup_f47f202a7ae7be2fe2a7682be72d19cf.setContent(html_a888bdd74671f0a6b4c0684fc8b62bf3);
#
#
#
#         marker_161cba16fceb34f8065b08ff92438e22.bindPopup(popup_f47f202a7ae7be2fe2a7682be72d19cf)
#         ;
#
#
#
#
#             var marker_1b296010b4e2b3532d5a90f1ab20a295 = L.marker(
#                 [37.330698, -121.888979],
#                 {}
#             ).addTo(map_c0455ae9b070d3b3e23415890bd30158);
#
#
#         var popup_2209e2535a1dc2a668e502dc10ec6951 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dfbea0cf1b0a601662931527ffdb17a2 = $(`&lt;div id=&quot;html_dfbea0cf1b0a601662931527ffdb17a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;San Jose Civic Center&lt;/div&gt;`)[0];
#                 popup_2209e2535a1dc2a668e502dc10ec6951.setContent(html_dfbea0cf1b0a601662931527ffdb17a2);
#
#
#
#         marker_1b296010b4e2b3532d5a90f1ab20a295.bindPopup(popup_2209e2535a1dc2a668e502dc10ec6951)
#         ;
#
#
#
#
#             var marker_a39cd479e6a9df2ffafe5d7b54b5ef7a = L.marker(
#                 [37.333988, -121.894902],
#                 {}
#             ).addTo(map_c0455ae9b070d3b3e23415890bd30158);
#
#
#         var popup_597729a555c874b1d074980b7d31cb16 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7f3b91e9681d545b0e6b4cf6cbd2c6a8 = $(`&lt;div id=&quot;html_7f3b91e9681d545b0e6b4cf6cbd2c6a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Santa Clara at Almaden&lt;/div&gt;`)[0];
#                 popup_597729a555c874b1d074980b7d31cb16.setContent(html_7f3b91e9681d545b0e6b4cf6cbd2c6a8);
#
#
#
#         marker_a39cd479e6a9df2ffafe5d7b54b5ef7a.bindPopup(popup_597729a555c874b1d074980b7d31cb16)
#         ;
#
#
#
#
#             var marker_8c5c5be8660416ef916a0501a5967161 = L.marker(
#                 [37.331415, -121.8932],
#                 {}
#             ).addTo(map_c0455ae9b070d3b3e23415890bd30158);
#
#
#         var popup_b0fcbcc7c09e53279178104c889ede81 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_597cacdd2144d4c788d5d1801c96bee8 = $(`&lt;div id=&quot;html_597cacdd2144d4c788d5d1801c96bee8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Adobe on Almaden&lt;/div&gt;`)[0];
#                 popup_b0fcbcc7c09e53279178104c889ede81.setContent(html_597cacdd2144d4c788d5d1801c96bee8);
#
#
#
#         marker_8c5c5be8660416ef916a0501a5967161.bindPopup(popup_b0fcbcc7c09e53279178104c889ede81)
#         ;
#
#
#
#
#             var marker_992b98a4f8516b8d42e034c204caf6f3 = L.marker(
#                 [37.336721, -121.894074],
#                 {}
#             ).addTo(map_c0455ae9b070d3b3e23415890bd30158);
#
#
#         var popup_47a0ef5b753414f7e66e73e07715d77b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ed4285e9f4820e5a942814022baeaaad = $(`&lt;div id=&quot;html_ed4285e9f4820e5a942814022baeaaad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;San Pedro Square&lt;/div&gt;`)[0];
#                 popup_47a0ef5b753414f7e66e73e07715d77b.setContent(html_ed4285e9f4820e5a942814022baeaaad);
#
#
#
#         marker_992b98a4f8516b8d42e034c204caf6f3.bindPopup(popup_47a0ef5b753414f7e66e73e07715d77b)
#         ;
#
#
#
#
#             var marker_64f3b89423512253219e9bdf55d6c01b = L.marker(
#                 [37.333798, -121.886943],

# %% [markdown]
# The map is created using [OpenStreetMap](http://www.openstreetmap.org/#map=5/51.500/-0.100), which is an open online mapping system that you can use just as you would use Google Maps or any other online map. Zoom in to San Francisco to see how the stations are distributed. Click on a marker to see which station it is.

# %% [markdown]
# You can also represent points on a map by colored circles. Here is such a map of the San Francisco bike stations.

# %%
sf = stations[stations['landmark'] == 'San Francisco']
sf_map_data = sf[['lat', 'long', 'name']]

sf_map = folium.Map(location=[sf['lat'].mean(), sf['long'].mean()], zoom_start=10)
for idx, row in sf_map_data.iterrows():
    folium.CircleMarker([row['lat'], row['long']], color='green', fill=True).add_to(sf_map)
sf_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2363afec05452e5d0a87b4405fd1b349 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2363afec05452e5d0a87b4405fd1b349&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2363afec05452e5d0a87b4405fd1b349 = L.map(
#                 &quot;map_2363afec05452e5d0a87b4405fd1b349&quot;,
#                 {
#                     center: [37.787746342857155, -122.40151734285716],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c89c12452ecef91a892b4aae9f1cbf83 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c89c12452ecef91a892b4aae9f1cbf83.addTo(map_2363afec05452e5d0a87b4405fd1b349);
#
#
#             var circle_marker_2236cc04f212f1f041a9e3e0a196fa72 = L.circleMarker(
#                 [37.795001, -122.39997],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2363afec05452e5d0a87b4405fd1b349);
#
#
#             var circle_marker_34feedd071c56f57d1f6337c68062f71 = L.circleMarker(
#                 [37.79728, -122.398436],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2363afec05452e5d0a87b4405fd1b349);
#
#
#             var circle_marker_452dab92bc0e938f7b03d585fc14fc45 = L.circleMarker(
#                 [37.794231, -122.402923],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2363afec05452e5d0a87b4405fd1b349);
#
#
#             var circle_marker_7dba80a23788558de88aa2276ba96db6 = L.circleMarker(
#                 [37.795425, -122.404767],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2363afec05452e5d0a87b4405fd1b349);
#
#
#             var circle_marker_9ee60e2ebc26a44ccccf125f1eea8eb1 = L.circleMarker(
#                 [37.788975, -122.403452],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2363afec05452e5d0a87b4405fd1b349);
#
#
#             var circle_marker_c9463c005d568174853c91ad581fa342 = L.circleMarker(
#                 [37.799953, -122.398525],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2363afec05452e5d0a87b4405fd1b349);
#
#
#             var circle_marker_f00cda4460092744bf618cabf50ecb27 = L.circleMarker(
#                 [37.790302, -122.390637

# %% [markdown]
# ## More Informative Maps: An Application of `join`
# The bike stations are located in five different cities in the Bay Area. To distinguish the points by using a different color for each city, let's start by using group to identify all the cities and assign each one a color.

# %%
cities = stations['landmark'].unique()
colors = pd.DataFrame({
    'city': cities,
    'color': ['blue', 'red', 'green', 'orange', 'purple']
})
colors
# Out:
#             city   color
# 0       San Jose    blue
# 1   Redwood City     red
# 2  Mountain View   green
# 3      Palo Alto  orange
# 4  San Francisco  purple

# %% [markdown]
# Now we can join `stations` and `colors` by `landmark`, and then select the columns we need to draw a map.

# %%
joined = stations.merge(colors, left_on='landmark', right_on='city')
colored = joined[['lat', 'long', 'name', 'color']]
colored.head()
# Out:
#          lat        long                               name color
# 0  37.329732 -121.901782  San Jose Diridon Caltrain Station  blue
# 1  37.330698 -121.888979              San Jose Civic Center  blue
# 2  37.333988 -121.894902             Santa Clara at Almaden  blue
# 3  37.331415 -121.893200                   Adobe on Almaden  blue
# 4  37.336721 -121.894074                   San Pedro Square  blue

# %%
colored_map = folium.Map(location=[colored['lat'].mean(), colored['long'].mean()], zoom_start=10)
for idx, row in colored.iterrows():
    folium.CircleMarker([row['lat'], row['long']], color=row['color'], fill=True, popup=row['name']).add_to(colored_map)
colored_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1d3a406c343af80af4672d89f9c1a210 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1d3a406c343af80af4672d89f9c1a210&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1d3a406c343af80af4672d89f9c1a210 = L.map(
#                 &quot;map_1d3a406c343af80af4672d89f9c1a210&quot;,
#                 {
#                     center: [37.59024338428571, -122.21841616428571],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1abb13165a56bb422a981af2b331b1c5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1abb13165a56bb422a981af2b331b1c5.addTo(map_1d3a406c343af80af4672d89f9c1a210);
#
#
#             var circle_marker_f121dad31380dfc91050513d66fc99f3 = L.circleMarker(
#                 [37.329732, -121.901782],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1d3a406c343af80af4672d89f9c1a210);
#
#
#         var popup_d290592b2e2acb53e450681655450a8e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5b84629b9b9876752e943058b9859ff3 = $(`&lt;div id=&quot;html_5b84629b9b9876752e943058b9859ff3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;San Jose Diridon Caltrain Station&lt;/div&gt;`)[0];
#                 popup_d290592b2e2acb53e450681655450a8e.setContent(html_5b84629b9b9876752e943058b9859ff3);
#
#
#
#         circle_marker_f121dad31380dfc91050513d66fc99f3.bindPopup(popup_d290592b2e2acb53e450681655450a8e)
#         ;
#
#
#
#
#             var circle_marker_27f041ac45c207a9753861f6f25bc672 = L.circleMarker(
#                 [37.330698, -121.888979],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1d3a406c343af80af4672d89f9c1a210);
#
#
#         var popup_51113b7b63020323d77032ce68bd04b9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_67d93306fee5016620cffaeb1133a056 = $(`&lt;div id=&quot;html_67d93306fee5016620cffaeb1133a056&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;San Jose Civic Center&lt;/div&gt;`)[0];
#                 popup_51113b7b63020323d77032ce68bd04b9.setContent(html_67d93306fee5016620cffaeb1133a056);
#
#
#
#         circle_marker_27f041ac45c207a9753861f6f25bc672.bindPopup(popup_51113b7b63020323d77032ce68bd04b9)
#         ;
#
#
#
#
#             var circle_marker_39019cf1de7da02e98413e42ae1597df = L.circleMarker(
#                 [37.333988, -121.894902],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1d3a406c343af80af4672d89f9c1a210);
#
#
#         var popup_98c25acef16f512b4449ea3a40639012 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fb2797ec4c651a89a10e0becb976edb0 = $(`&lt;div id=&quot;html_fb2797ec4c651a89a10e0becb976edb0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Santa Clara at Almaden&lt;/div&gt;`)[0];
#                 popup_98c25acef16f512b4449ea3a40639012.setContent(html_fb2797ec4c651a89a10e0becb976edb0);
#
#
#
#         circle_marker_39019cf1de7da02e98413e42ae1597df.bindPopup(popup_98c25acef16f512b4449ea3a40639012)
#         ;
#
#
#
#
#             var circle_marker_800129bf57c6b3e2d5d4b06187589719 = L.circleMarker(
#                 [37.331415, -121.8932],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true

# %% [markdown]
# Now the markers have five different colors for the five different cities.

# %% [markdown]
# To see where most of the bike rentals originate, let's identify the start stations:

# %%
starts = commute.groupby('Start Station').size().reset_index(name='count').sort_values(by='count', ascending=False)
starts.head()
# Out:
#                                     Start Station  count
# 49       San Francisco Caltrain (Townsend at 4th)  25858
# 50        San Francisco Caltrain 2 (330 Townsend)  21523
# 23           Harry Bridges Plaza (Ferry Building)  15543
# 65  Temporary Transbay Terminal (Howard at Beale)  14298
# 2                                 2nd at Townsend  13674

# %% [markdown]
# We can include the geographical data needed to map these stations, by first joining `starts` with `stations`:

# %%
station_starts = stations.merge(starts, left_on='name', right_on='Start Station')
station_starts.head()
# Out:
#    station_id                               name        lat        long  \
# 0           2  San Jose Diridon Caltrain Station  37.329732 -121.901782
# 1           3              San Jose Civic Center  37.330698 -121.888979
# 2           4             Santa Clara at Almaden  37.333988 -121.894902
# 3           5                   Adobe on Almaden  37.331415 -121.893200
# 4           6                   San Pedro Square  37.336721 -121.894074
#
#    dockcount  landmark installation                      Start Station  count
# 0         27  San Jose     8/6/2013  San Jose Diridon Caltrain Station   4899
# 1         15  San Jose     8/5/2013              San Jose Civic Center    574
# 2         11  San Jose     8/6/2013             Santa Clara at Almaden   1888
# 3         19  San Jose     8/5/2013                   Adobe on Almaden    522
# 4         15  San Jose     8/7/2013                   San Pedro Square   1321

# %% [markdown]
# Now we extract just the data needed for drawing our map, adding a color and an area to each station. The area is 0.3 times the count of the number of rentals starting at each station, where the constant 0.3 was chosen so that the circles would appear at an appropriate scale on the map.

# %%
merged_df = colored.merge(station_starts, left_on='name', right_on='Start Station', suffixes=('', '_y'))
starts_map_data = merged_df[['lat', 'long', 'name', 'color', 'count']]
starts_map_data.head()
# Out:
#          lat        long                               name color  count
# 0  37.329732 -121.901782  San Jose Diridon Caltrain Station  blue   4899
# 1  37.330698 -121.888979              San Jose Civic Center  blue    574
# 2  37.333988 -121.894902             Santa Clara at Almaden  blue   1888
# 3  37.331415 -121.893200                   Adobe on Almaden  blue    522
# 4  37.336721 -121.894074                   San Pedro Square  blue   1321

# %%
starts_map = folium.Map(location=[starts_map_data['lat'].mean(), starts_map_data['long'].mean()], zoom_start=10)
for idx, row in starts_map_data.iterrows():
    folium.CircleMarker([row['lat'], row['long']], radius=row['count'] * 0.006, color=row['color'], fill=True, popup=row['name']).add_to(starts_map)
starts_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ed55a4f45e5d5404bc2562ee12376546 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ed55a4f45e5d5404bc2562ee12376546&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ed55a4f45e5d5404bc2562ee12376546 = L.map(
#                 &quot;map_ed55a4f45e5d5404bc2562ee12376546&quot;,
#                 {
#                     center: [37.58430348382353, -122.21295459558823],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a4dc2c628e9da76398502643cd7e2831 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a4dc2c628e9da76398502643cd7e2831.addTo(map_ed55a4f45e5d5404bc2562ee12376546);
#
#
#             var circle_marker_dbd6ba25dd998c34ef47b7f03c2f5080 = L.circleMarker(
#                 [37.329732, -121.901782],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 29.394000000000002, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ed55a4f45e5d5404bc2562ee12376546);
#
#
#         var popup_2104d42966fad3edada51a617607227e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_712e5916d430e6e0f25809543d58e838 = $(`&lt;div id=&quot;html_712e5916d430e6e0f25809543d58e838&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;San Jose Diridon Caltrain Station&lt;/div&gt;`)[0];
#                 popup_2104d42966fad3edada51a617607227e.setContent(html_712e5916d430e6e0f25809543d58e838);
#
#
#
#         circle_marker_dbd6ba25dd998c34ef47b7f03c2f5080.bindPopup(popup_2104d42966fad3edada51a617607227e)
#         ;
#
#
#
#
#             var circle_marker_630450c87b946a0b948a2a83db304a10 = L.circleMarker(
#                 [37.330698, -121.888979],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3.444, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ed55a4f45e5d5404bc2562ee12376546);
#
#
#         var popup_3964a34f2b7edeae99f607a7832b1af9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ecea3aa671bf077c8483594c401c63db = $(`&lt;div id=&quot;html_ecea3aa671bf077c8483594c401c63db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;San Jose Civic Center&lt;/div&gt;`)[0];
#                 popup_3964a34f2b7edeae99f607a7832b1af9.setContent(html_ecea3aa671bf077c8483594c401c63db);
#
#
#
#         circle_marker_630450c87b946a0b948a2a83db304a10.bindPopup(popup_3964a34f2b7edeae99f607a7832b1af9)
#         ;
#
#
#
#
#             var circle_marker_dd281da40007728d79db71c9d52738de = L.circleMarker(
#                 [37.333988, -121.894902],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 11.328, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ed55a4f45e5d5404bc2562ee12376546);
#
#
#         var popup_d4b33c429aa10309e5a7ae0337d34d8d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c90efbeb6a708f9981f9fe4ae50b2eda = $(`&lt;div id=&quot;html_c90efbeb6a708f9981f9fe4ae50b2eda&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Santa Clara at Almaden&lt;/div&gt;`)[0];
#                 popup_d4b33c429aa10309e5a7ae0337d34d8d.setContent(html_c90efbeb6a708f9981f9fe4ae50b2eda);
#
#
#
#         circle_marker_dd281da40007728d79db71c9d52738de.bindPopup(popup_d4b33c429aa10309e5a7ae0337d34d8d)
#         ;
#
#
#
#
#             var circle_marker_aa9c1f1bf834aa24b3a5c38b43459bba = L.circleMarker(
#                 [37.331415, -121.8932],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null,

# %% [markdown]
# That huge blob in San Francisco shows that the eastern section of the city is the unrivaled capital of bike rentals in the Bay Area.
