# %% [markdown]
# # Hypothesis Testing

# %% [markdown]
# ## What are Hypothesis?

# %% [markdown]
# If a person claims that coffee makes you awake at night, or sleep makes you taller, or that drug X relieves your headache, how can we verify these claims scientifically? Enter Hypothesis Testing. A Hypothesis, simply put, is a statement that we want to verify if it is true or not.
#
# The ***Null Hypothesis*** ($H_0$) can be thought of as the implied hypothesis. “Null” meaning “nothing.” This hypothesis states that there is no difference between groups or no relationship between variables. The null hypothesis is a presumption of status quo or no change.
#
# The ***Alternative Hypothesis*** ($H_a$) is also known as the claim. This hypothesis should state what you expect the data to show, based on your research on the topic.
#
# Examples:
#
# **Coffee and IQ**
#
# - $H_0$: Drinking coffee does not affect IQ.
# - $H_a$: Drinking coffee increases IQ.
#
# **Drug X and Headache**
#
# - $H_0$: Drug X does not decrease recovery time from headache.
# - $H_a$: Drug X decreases recovery time from headache.

# %% [markdown]
# Hypothesis testing undergoes three main steps:
#
# 1. Experiment Design, Conducting Trials and Collecting Data
# 2. Inference about each group
# 3. Statistical Significance
#
# Let's go through each step in detail.

# %% [markdown]
# ### Step 1: Experiment Design, Conducting Trials and Collecting Data
#
# We need to collect data while avoiding bias. The best way scientists know of is: *Randomization*.

# %% [markdown]
# > ***Randomization*** is the process of assigning participants to treatment and control groups, assuming that each participant has an equal chance of being assigned to any group. ([NIH](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2267325/#:~:text=What%20Is%20Randomization%3F,being%20assigned%20to%20any%20group))

# %% [markdown]
# In *Random Experiments*, we have two groups:
#
# - ***Test or Treatment Group***: a group where the treament is applied
# - ***Control Group***: a group where no treatment is applied (often, a placebo is given to eliminate psychological effects)

# %% [markdown]
# ### Step 2: Inference about each group
#
# Let's first state our Hypotheses:
# - The Null Hypothesis $H_0$ states that the $\mu_a$ (mean) of the Test Group is equal to the $\mu_0$ of the Control Group.
# - The Alternative Hypothesis $H_a$ states that the $\mu_a$ of the Test Group is not equal to the $\mu_0$ of the Control Group.
#
# These are two populations (Treatment and Control). We choose our Confidence Level ($95\%$ by convention) and estimate their means: $\mu_0$ and $\mu_a$ through repeated (say: $k = 1000$) large (say: $n = 50$) sampling. The goes back to the [Central Limit Theorem](../techniques/central_limit_theorem.ipynb).

# %% [markdown]
# ### Step 3: Statistical Significance
#
# We know have two estimates of the means: $\mu_0$ and $\mu_a$. But how can we be sure that the difference between them is not due to random chance? This is where *Statistical Significance* comes in.
#
# The **t-test** is a statistical test that qualifies the difference between two means as being statistically significant or not. For a *Confidence Level* $CI = 95\%$, the t-test is significant if the p-value (the outcome of the t-test) is less than the *Significance Level* $\alpha = 0.05$.
#
# In other words, the ***p-value*** is the probability of observing a test statistic as extreme as the one computed from the sample data (Treatment Group), assuming that the null hypothesis ($\mu_a = \mu_0$) is true.
#
# Remember, the p-value will always be tied to a null hypothesis.

# %% [markdown]
# ### Step 4: Check for Type I and Type II Errors
#
# - **Type I Error (a.k.a False Positive)**: mistakenly concluding an effect is real (when it is due to chance)
#     - example: the test result says you have coronavirus, but you actually don’t
#     - example: the test result says the drug is effective, but it actually isn’t
# - **Type II Error (a.k.a False Negative)**: mistakenly concluding an effect is due to chance (when it is real)
#     - example: the test result says you don’t have coronavirus, but you actually do
#     - example: the test result says the drug is not effective, but it actually is

# %% [markdown]
# ### Summary of Hypothesis Testing
#
# 1. State the null hypothesis $H_0$ and the alternative hypothesis $H_a$
# 2. Choose a significance level $\alpha$ (0.05 by scientific convention) or conversely a confidence level $(1 - \alpha)$
# 3. Calculate the p-value using a statistical test (say t-test)
#     - Make a decision: reject, or fail to reject the null hypothesis
# 4. Monitor for Type I and Type II errors

# %% [markdown]
# # Statistical Tests

# %% [markdown]
# ### z-test
#
# A **z-test** is a statistical test used to determine whether two population *means* are significantly different. The *z-statistic* is given by:
#
# $$
# z = \frac{\bar x - \mu}{\sigma / \sqrt{n}}
# $$
#
# The issue with the z-test is that it requires the population standard deviation ($\sigma$) to be known. In practice, this is rarely the case. Therefore, the t-test is more commonly used.

# %% [markdown]
# ### t-test
#
# In a **t-test**, a *t-statistic* is the difference between the hyopthesized mean $\mu$ and a sample mean $\bar x$ divided by the standard error $\frac{s}{\sqrt{n}}$, instead of the standard deviation $\sigma$ since it is unknown.
#
# $$
# t = \frac{\bar x - \mu}{s / \sqrt{n}}
# $$

# %% [markdown]
# ### z- and t-distributions
#
# It has been noted that the t-distribution is similar to the normal distribution, but with heavier tails. Hence, it is a good approximation for the normal distribution.
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/2/2a/Comparing_the_Standard_Normal_Distribution_and_Student%27s_T_Distribution.png" height="260">
#
# [Figure](https://commons.wikimedia.org/wiki/File:Comparing_the_Standard_Normal_Distribution_and_Student%27s_T_Distribution.png#filelinks): Comparing the Standard Normal Distribution and Student's T Distribution.

# %% [markdown]
# # How to choose between statistical test?

# %% [markdown]
# <img src="../assets/t-test.png">

# %% [markdown]
# ## Case: Compare a Sample Against the Population
#
# Usually means we are making a comparison against a historic or global value. Examples:
#
# - To compare the average height of a group of students to the average height of the general population.
# - To compare the average IQ of a group of people to the average IQ of the general population.
# - To compare the average cholesterol levels of a group of people to the recommended cholesterol levels.

# %% [markdown]
# ## Case: Compare Independent Samples
#
# Control group vs. test group in an experiment:
# - Control group takes a placebo, test group takes the treatment drug
# - Female vs. male
# - Americans vs. Europeans

# %% [markdown]
# ## Case: Paired Samples
#
# There are two cases for paired samples:
#
# 1. One group: usually looking for **comparison**
# 2. Two paired groups: usually seeking **relationship**
#
# It is as follows:
#
# 1. One group, but two measurements (a group with the intervention and a group without the intervention).
#     1. Same measurement, twice on the same group:
#         - Grip strength — before vs. after eating spinach
#         - Quiz scores — iPad notes vs. paper notes
#         - Performance — with afternoon nap vs. without it
#     2. Two measurements, on the same group:
#         - Temperature under right armpit and under left armpit
#         - BMI and Systolic Blood Pressure
#
# 2. Two groups where each record in the 1st group (sample) is naturally paired with a record in the 2nd group. For instance: twins, husband-wife, mother-baby, etc.

# %% [markdown]
# ## Examples for Cases

# %% [markdown]
# #### Hypothesis $H_1$: the average height of NBA player is higher than the average height of the general population

# %%
# Source 1 NBA Heights: https://github.com/simonwarchol/NBA-Height-Weight/blob/master/CSVs/total.csv
# Source 2 Human Heights: https://www.kaggle.com/datasets/burnoutminer/heights-and-weights-dataset

import pandas as pd

nba = pd.read_csv('../datasets/nba/nba_heights.csv')

nba.describe()
# Out:
#          h_meters        h_in
# count  435.000000  435.000000
# mean     2.012483   79.209195
# std      0.090078    3.573444
# min      1.750000   69.000000
# 25%      1.960000   77.000000
# 50%      2.030000   80.000000
# 75%      2.080000   82.000000
# max      2.290000   90.000000

# %%
humans = pd.read_csv('../datasets/nba/SOCR-HeightWeight.csv')

humans.describe()
# Out:
#               Index  Height(Inches)  Weight(Pounds)
# count  25000.000000    25000.000000    25000.000000
# mean   12500.500000       67.993114      127.079421
# std     7217.022701        1.901679       11.660898
# min        1.000000       60.278360       78.014760
# 25%     6250.750000       66.704397      119.308675
# 50%    12500.500000       67.995700      127.157750
# 75%    18750.250000       69.272958      134.892850
# max    25000.000000       75.152800      170.924000

# %%
from scipy import stats

# significance level
alpha = 0.05

# 1 sample t-test
t_statistic, p_value = stats.ttest_1samp(
    nba['h_in'],
    humans['Height(Inches)'].mean(),
    alternative="greater",
)

print(f"t-statistic: {t_statistic}")
print(f"p-value: {p_value}")
print("significant!" if p_value <= alpha else "not enough evidence")
# Out:
# t-statistic: 65.46344283953596
# p-value: 2.5313655741516803e-227
# significant!

# %%
import seaborn as sns

# plot smooth kde distribution of body mass for two sexes overlapping
sns.kdeplot(nba, x='h_in', fill=True)

# vertical line at the mean of the height for both
import matplotlib.pyplot as plt

plt.axvline(humans['Height(Inches)'].mean(), color='red', linestyle='--')
plt.axvline(nba['h_in'].mean(), color='blue', linestyle='--')

# %%
import seaborn as sns

penguins = sns.load_dataset('penguins')

penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
# drop na
penguins.dropna(inplace=True)

# %% [markdown]
# #### Hypothesis $H_2$: male penguins weigh more than female penguins

# %%
from scipy import stats

# significance level
alpha = 0.05

# two-sample t-test
t_statistic, p_value = stats.ttest_ind(
    penguins.loc[penguins["sex"] == "Male", 'body_mass_g'],
    penguins.loc[penguins["sex"] == "Female", 'body_mass_g'],
    alternative="greater",
)

print(f"t-statistic: {t_statistic}")
print(f"p-value: {p_value}")
print("significant!" if p_value <= alpha else "not enough evidence")
# Out:
# t-statistic: 8.541720337994516
# p-value: 2.448623375798112e-16
# significant!

# %% [markdown]
# Let's look at the boxplot:

# %%
sns.boxplot(penguins, y='body_mass_g', hue='sex')
# Out:
# <Axes: ylabel='body_mass_g'>

# %% [markdown]
# Let's look at the density plot:

# %%
# plot smooth kde distribution of body mass for two sexes overlapping
sns.kdeplot(penguins, x='body_mass_g', hue='sex', fill=True)

# vertical line at the mean of the body mass for male and another for female
import matplotlib.pyplot as plt

plt.axvline(penguins.loc[penguins['sex'] == 'Male']['body_mass_g'].mean(), color='blue', linestyle='--')
plt.axvline(penguins.loc[penguins['sex'] == 'Female']['body_mass_g'].mean(), color='orange', linestyle='--')

# %%
import seaborn as sns

tips = sns.load_dataset('tips')

tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.dropna(inplace=True)

# %% [markdown]
# #### Hypothesis $H_3$: smokers give higher tips than non-smokers

# %%
from scipy import stats

# significance level
alpha = 0.05

# two-sample t-test
t_statistic, p_value = stats.ttest_ind(
    tips.loc[tips["smoker"] == "Yes", 'tip'],
    tips.loc[tips["smoker"] == "No", 'tip'],
    alternative="greater",
)

print(f"t-statistic: {t_statistic}")
print(f"p-value: {p_value}")
print("significant!" if p_value <= alpha else "not enough evidence")
# Out:
# t-statistic: 0.09222805186888201
# p-value: 0.4632965761122488
# not enough evidence

# %% [markdown]
# Let's look at the box plot:

# %%
sns.boxplot(tips, y='tip', hue='smoker')
# Out:
# <Axes: ylabel='tip'>

# %%
# plot smooth kde distribution of body mass for two sexes overlapping
sns.kdeplot(tips, x='tip', hue='smoker', fill=True)

# vertical line at the mean of the body mass for male and another for female
import matplotlib.pyplot as plt

plt.axvline(tips.loc[tips['smoker'] == 'Yes']['tip'].mean(), color='blue', linestyle='--')
plt.axvline(tips.loc[tips['smoker'] == 'No']['tip'].mean(), color='orange', linestyle='--')

# %% [markdown]
# ### Hypothesis $H_4$: spinach increases grip strength
#
# Statistical test: Two paired samples (one group, same measurement, twice)

# %%
import pandas as pd
from scipy import stats

# Determine significance level
alpha = 0.05

grip = pd.DataFrame({
    "before": [50, 52, 55, 53, 54, 56, 57, 58, 59, 60, 61, 62, 63, 64, 65, 66, 67, 68, 70, 72],
    "after": [60, 68, 50, 55, 59, 61, 62, 63, 64, 65, 66, 67, 68, 70, 72, 73, 75, 76, 77, 78],
})

# two-sample, related, t-test
t_statistic, p_value = stats.ttest_rel(
    grip['after'],
    grip['before'],
    alternative="greater",
)

print(f"t-statistic: {t_statistic}")
print(f"p-value: {p_value}")
print("significant!" if p_value <= alpha else "not enough evidence")
# Out:
# t-statistic: 6.907558493188381
# p-value: 6.898776102555169e-07
# significant!

# %%
grip.describe()
# Out:
#          before      after
# count  20.00000  20.000000
# mean   60.60000  66.450000
# std     6.26099   7.500702
# min    50.00000  50.000000
# 25%    55.75000  61.750000
# 50%    60.50000  66.500000
# 75%    65.25000  72.250000
# max    72.00000  78.000000

# %%
# plot smooth kde distribution of body mass for two sexes overlapping
ax = sns.kdeplot(grip, x='before', fill=True)
sns.kdeplot(grip, x='after', fill=True, ax=ax)

# legend
plt.legend(['before', 'after'])

# vertical line at the mean of before and after
import matplotlib.pyplot as plt

plt.axvline(grip['before'].mean(), color='blue', linestyle='--')
plt.axvline(grip['after'].mean(), color='orange', linestyle='--')

# %% [markdown]
# ## One-way ANOVA
#
# The one-way ANOVA tests the null hypothesis that two or more groups have the same population mean. The test is applied to samples from two or more groups, possibly with differing sizes.
#
# #### Hypothesis $H_5$: weights of penguins across species do differ

# %%
from scipy.stats import f_oneway

penguins = sns.load_dataset('penguins')

penguins.dropna(inplace=True)

# Determine significance level
alpha = 0.05

# one-way ANOVA
f_statistic, p_value = f_oneway(
    penguins.loc[penguins["species"] == "Adelie", 'body_mass_g'],
    penguins.loc[penguins["species"] == "Chinstrap", 'body_mass_g'],
    penguins.loc[penguins["species"] == "Gentoo", 'body_mass_g'],
)

print(f"f-statistic: {f_statistic}")
print(f"p-value: {p_value}")
print("significant!" if p_value <= alpha else "not enough evidence")
# Out:
# f-statistic: 341.8948949481461
# p-value: 3.74450512630046e-81
# significant!

# %%
# plot smooth kde distribution of body mass
sns.kdeplot(penguins, x='body_mass_g', hue='species', fill=True)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Density'>

# %%
# boxplot
sns.boxplot(penguins, y='body_mass_g', x='species')
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %% [markdown]
# # Chi-Squared ($\chi^2$) Test
#
# The chi-squared test is used to test for **association between two categorical variables**. However, it doesn't quantify how strong this association is.

# %% [markdown]
# #### Hypothesis $H_6$: smoking (yes/no) is associated with time of visit (lunch/dinner)

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Load the tips dataset from Seaborn
tips = sns.load_dataset("tips")
# tips.dropna(inplace=True)
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Create a contingency table of the smoker and time variables
contingency_table = pd.crosstab(
    columns=tips["smoker"],
    index=tips["time"],
    values=tips["tip"],
    aggfunc="count"
)
contingency_table
# Out:
# smoker  Yes   No
# time
# Lunch    23   45
# Dinner   70  106

# %%
contingency_table.sum().sum()
# Out:
# 244

# %%
plt.figure(figsize=(6, 3))
normalized_table = contingency_table / contingency_table.sum().sum()
sns.heatmap(data=normalized_table, annot=True, cmap="Blues", fmt=".1%");

# %%
import scipy.stats as st

# significance level
alpha = 0.05

# Perform the chi-squared test
result = st.chi2_contingency(contingency_table)

print(f"p-value: {result.pvalue}")
print("significant!" if result.pvalue <= alpha else "not enough evidence")
# Out:
# p-value: 0.4771485672079724
# nope
